# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sinr import graph_embeddings as ge

# %%
model = ge.SINrVectors("/export/home/lium/sguillot/git/sinr3/sinr/sinr_news")
model.load()
# Out:
# /lium/buster1/dugue/miniconda3-2023/envs/hackatal23/lib/python3.9/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator NearestNeighbors from version 1.1.1 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
import pickle as pk
f = open("/lium/raid01_c/sguillot/Corpus/HackaTAL/fi.pk", 'rb')
dico = pk.load(f)
f.close()

# %%
dico
# Out:
# defaultdict(int,
#             {'visant': 14,
#              'à': 21,
#              'l': 8,
#              'proposition': 1,
#              'de': 65,
#              'qui': 9,
#              'aplanisse': 1,
#              'toute': 2,
#              'en': 8,
#              'consiste': 1,
#              '2019': 1,
#              'afin': 2,
#              'article': 2,
#              '1er': 3,
#              'n': 7,
#              '2017': 2,
#              'organique': 3,
#              'pensés': 1,
#              'constitutionnelle': 8,
#              'seront': 1,
#              'une': 12,
#              'bioéthique': 6,
#              'pourrait': 3,
#              'désormais': 1,
#              'républicaine': 1,
#              'il': 4,
#              'impose': 2,
#              'pour': 13,
#              'est': 11,
#              'manifestement': 6,
#              'qu': 1,
#              'au': 4,
#              'doit': 3,
#              'être': 3,
#              'du': 14,
#              'juillet': 1,
#              'interdiction': 1,
#              'et': 23,
#              'le': 13,
#              'programmation': 8,
#              'maire': 1,
#              'dite': 2,
#              'asile': 4,
#              'celles': 1,
#              'finances': 19,
#              'portant': 5,
#              'mesures': 2,
#              'd': 6,
#              'égalité': 1,
#              'darmanin': 1,
#              'macron': 1,
#              'sortie': 2,
#              'mises': 1,
#              'soit': 1,
#              'remise': 1,
#              'juilet': 1,
#              'dans': 3,
#              'antiterrorisme': 1,
#              'les': 4,
#              'but': 1,
#              'casse': 1,
#              'dont': 1,
#              'mercredi': 1,
#              'juin': 1,
#              'anti': 4,
#              'manifestant': 1,
#              'manifestants': 1,
#              'dès': 1,
#              'la': 9,
#              'référendaire': 2,
#              'casseurs': 1,
#              'transpartisane': 1,
#              'un': 4,
#              'travail': 1,
#              'pacte': 2,
#              'egalim': 3,
#              'des': 3,
#              'c': 1,
#              'ferroviaire': 1,
#              'instaurant': 2,
#              'contre': 2,
#              'orientation': 3,
#              'macroniste': 1,
#              'sur': 7,
#              'ni': 1,
#              'affiché': 1,
#              'agriculture': 1,
#              'ces': 1,
#              'comme': 1,
#              'française': 1,
#              'depuis': 1,
#              'respectueux': 1,
#              'sert': 1,
#              'aussi': 2,
#              'déférée': 1,
#              'porte': 6,
#              'extension': 1,
#              'collomb': 1,
#              'financement': 5,
#              'interdire': 2,
#              'ayant': 1,
#              'habilitation': 1,
#              'énergie': 1,
#              'climat': 4,
#              'inconstitutionnelle': 1,
#              'facilitera': 1,
#              'donne': 1,
#              'cesse': 1,
#              'subordonne': 1,
#              'a': 5,
#              'interdisait': 2,
#              '(2018)': 1,
#              'malbouffe': 1,
#              '(fev': 1,
#              'touillettes': 1,
#              '»': 3,
#              'évolué': 1,
#              '«': 9,
#              'confortant': 5,
#              '1905,': 1,
#              'laïque': 2,
#              '1905.': 2,
#              '1905': 1,
#              'carle,': 1,
#              'sécurité': 7,
#              'nationalisation': 1,
#              'aujourd’hui': 1,
#              'transmis': 1,
#              'aux': 2,
#              'antiterroriste': 1,
#              'prévoit': 2,
#              'que': 1,
#              'pénale': 1,
#              'plus': 1,
#              'd’urgence': 3,
#              'autorise': 1,
#              'finances,': 1,
#              'ratification': 1,
#              'no': 1,
#              '2020-290': 1,
#              'rectificatif.': 1,
#              'encore': 2,
#              'relatif': 4,
#              '“pour': 2,
#              'globale,': 1,
#              'club': 1,
#              'globale.': 2,
#              'reste': 1,
#              'celle': 1,
#              'déposant': 1,
#              'atteinte': 3,
#              'accentuant': 1,
#              'qui,': 1,
#              '29': 1,
#              '30': 1,
#              'sanitaire,': 1,
#              'd’état': 1,
#              '»,': 1,
#              'menacent': 1,
#              'aiderait': 1,
#              'prétendument': 2,
#              'consacre': 1,
#              'va': 1,
#              'favoriser': 1,
#              'induit': 1,
#              'tend': 1,
#              'directive': 1,
#              'madame': 1,
#              'profondément': 1,
#              'nuisible': 1,
#              'gouvernement': 1,
#              'séparatisme': 1,
#              'climat.': 1,
#              'qu’ils': 1,
#              'jugent': 1,
#              'climat,': 1,
#              'utilisant': 1,
#              'respect': 1,
#              'ne': 3,
#              'contient': 1,
#              'debré': 1,
#              'carle.': 1,
#              'toutes': 1,
#              'blanquer': 1,
#              'accorde': 1,
#              'pourtant,': 1,
#              'initial': 1,
#              'gouvernementale.': 1,
#              'sans': 1,
#              'globale': 3,
#              'deux': 1,
#              'autorisant': 1,
#              'contrevient': 1,
#              'renvoient': 1,
#              'vers': 1,
#              '23': 1,
#              '9': 1,
#              '“climat”.': 1,
#              'faire': 1,
#              'pénale.': 1,
#              'd’ailleurs,': 1,
#              '[···]': 2,
#              'imposent': 1,
#              'vous': 1,
#              ';': 1,
#              'qu’à': 1,
#              '12': 1,
#              'son': 2,
#              'n°': 3,
#              '2001-504': 1,
#              '55-385': 1,
#              '2015-1501': 1,
#              'rendu': 1,
#              'contesté,': 1,
#              'méconnaissent': 1,
#              'l’objectif': 1,
#              'implique': 1,
#              'qu’une': 1,
#              'ont': 1,
#              'été': 1,
#              'articles': 1,
#              'imposerait': 1,
#              'donc': 1,
#              'contesté.': 1,
#              'sont': 2,
#              'trop': 1,
#              'ainsi': 1,
#              'lutte': 1,
#              'prive': 1,
#              's’inscrivent': 1,
#              'si': 1,
#              'l’état': 1,
#              'immigration.': 1,
#              'relatifs': 1,
#              'proposent': 1,
#              'renforçant': 1,
#              'contraires': 1,
#              'el': 1,
#              'khomri,': 1,
#              'veil': 1,
#              'progrès': 1,
#              'constitutionnelle,': 1,
#              'pénicaud,': 1,
#              'diverses': 1,
#              'avia': 1,
#              'censurée': 1,
#              'humaine': 1,
#              'finances.': 1,
#              ':': 1,
#              'tri': 1,
#              'finalement': 1,
#              'votée': 1,
#              'immigration,': 1,
#              '1881': 1,
#              'nos': 1,
#              'nous': 1,
#              'locataires.': 1,
#              'mussolinienne.': 1,
#              'jurisprudence': 1,
#              'déféré': 1,
#              'contreviennent': 1,
#              'mais': 1,
#              'claeys': 1,
#              'leonetti': 1,
#              'impossible': 1,
#              'élan': 1,
#              'ce': 1,
#              'détriment': 1})

# %%
import numpy as np
vector = model.transfert_hackatal("loi", dico)
np.sum(vector)
# Out:
# 3.8232697137852867

# %%
model.most_similar_vector("loi",vector.reshape(1, -1))
# Out:
# {'object ': 'loi',
#  'neighbors ': [('rectificative', 0.47),
#   ('rendues', 0.43),
#   ('assainir', 0.38),
#   ('dgfip', 0.37),
#   ('administrations', 0.36),
#   ('rationalisation', 0.28),
#   ('imprévues', 0.28),
#   ('excessives', 0.27),
#   ('dépenses', 0.27),
#   ('avantprojet', 0.27),
#   ('wolfgang', 0.26),
#   ('comptes', 0.24),
#   ('cassation', 0.24),
#   ('finances', 0.24),
#   ('pourvoi', 0.24),
#   ('spf', 0.24),
#   ('privées', 0.24),
#   ('suprême', 0.24),
#   ('ordonnateurs', 0.24),
#   ('ordonnateur', 0.22),
#   ('intérieure', 0.22),
#   ('elyes', 0.22),
#   ('constitutionnelle', 0.22),
#   ('équilibrer', 0.22)]}

# %%
model.get_obj_stereotypes_vector(vector)
# Out:
# [{'dimension': 2965,
#   'value': True,
#   'stereotypes': [(0.1, 'dgfip'),
#    (0.09, 'rectificative'),
#    (0.07, 'akinwumi')]},
#  {'dimension': 5231,
#   'value': True,
#   'stereotypes': [(0.03, 'saintesophie'),
#    (0.02, 'citait'),
#    (0.02, 'offenses')]},
#  {'dimension': 3008,
#   'value': True,
#   'stereotypes': [(0.14, 'cassation'), (0.12, 'pourvoit'), (0.12, 'pourvoi')]},
#  {'dimension': 6506,
#   'value': True,
#   'stereotypes': [(0.06, 'pluriannuelle'),
#    (0.03, 'éclectique'),
#    (0.03, 'quinquennale')]},
#  {'dimension': 7646,
#   'value': True,
#   'stereotypes': [(0.1, 'routière'), (0.09, 'dgsi'), (0.08, 'glissières')]}]

# %%
import pickle as pk
f = open("/lium/raid01_c/sguillot/Corpus/HackaTAL/rn.pk", 'rb')
dico = pk.load(f)
f.close()
vector = model.transfert_hackatal("loi", dico)
model.most_similar_vector("loi",vector.reshape(1, -1))
# Out:
# {'object ': 'loi',
#  'neighbors ': [('publiques', 0.39),
#   ('rendues', 0.35),
#   ('administrations', 0.32),
#   ('assainir', 0.32),
#   ('dgfip', 0.31),
#   ('extraditions', 0.3),
#   ('ordonnances', 0.28),
#   ('bape', 0.28),
#   ('acharné', 0.28),
#   ('accompli', 0.27),
#   ('finances', 0.27),
#   ('imprévues', 0.27),
#   ('collaboratif', 0.26),
#   ('titanesque', 0.26),
#   ('rationalisation', 0.26),
#   ('avantprojet', 0.25),
#   ('fruit', 0.25),
#   ('relatif', 0.25),
#   ('réforme', 0.25),
#   ('sape', 0.24),
#   ('colossal', 0.24),
#   ('adopté', 0.24),
#   ('ambitieux', 0.23),
#   ('structurant', 0.23)]}

# %%
dico
# Out:
# defaultdict(int,
#             {'du': 84,
#              'mars': 3,
#              'la': 61,
#              'loi': 4,
#              'garantit': 3,
#              'les': 34,
#              'n': 20,
#              'comme': 5,
#              'tout': 5,
#              'de': 223,
#              'émanant': 1,
#              'finances': 45,
#              'plus': 6,
#              'd': 26,
#              'équité': 1,
#              'républicaine': 8,
#              'nous': 6,
#              'hadopi': 8,
#              'et': 78,
#              'peur': 1,
#              'des': 22,
#              'cités': 1,
#              'il': 12,
#              'appartient': 1,
#              'achetons': 6,
#              'français': 6,
#              'instituant': 1,
#              'le': 70,
#              'porté': 1,
#              'par': 21,
#              'risque': 3,
#              'fort': 2,
#              'programmation': 29,
#              'taubira': 8,
#              'visant': 24,
#              'lorsqu': 2,
#              'adoptée': 4,
#              'hier': 1,
#              'consommation': 1,
#              'ne': 17,
#              'envisage': 1,
#              'évoque': 1,
#              'répercuter': 1,
#              'en': 49,
#              'france': 2,
#              'dati': 8,
#              'profit': 1,
#              'ump': 1,
#              'tous': 3,
#              'organique': 9,
#              'alur': 1,
#              'accès': 1,
#              'j': 2,
#              'sacrée': 1,
#              'réalité': 1,
#              'est': 41,
#              'inacceptable': 1,
#              'copinage': 1,
#              'expose': 1,
#              'exception': 1,
#              'loppsi': 1,
#              'jeu': 2,
#              'française': 11,
#              'l': 45,
#              'hypocrisie': 1,
#              'étrangère': 1,
#              'facilitant': 1,
#              'antiterroriste': 2,
#              'dont': 3,
#              'santé': 6,
#              'macron': 23,
#              'rappelle': 1,
#              'consiste': 1,
#              'inique': 1,
#              'conforme': 2,
#              'réglerons': 1,
#              'gouvernemental': 1,
#              'sur': 100,
#              'y': 1,
#              'liberté': 2,
#              'qui': 38,
#              'illustre': 1,
#              'touraine': 7,
#              'dite': 13,
#              'installera': 1,
#              'totalement': 2,
#              'tendant': 4,
#              'à': 52,
#              'confie': 1,
#              'aux': 10,
#              'mais': 2,
#              'finance': 6,
#              'notre': 9,
#              'insignifiante': 1,
#              'travail': 29,
#              'symbolisent': 1,
#              'nouvelle': 2,
#              'sensée': 1,
#              'répondre': 1,
#              'imposée': 1,
#              'votée': 8,
#              'organisée': 1,
#              'c': 4,
#              'pour': 33,
#              'seront': 1,
#              'efficaces': 1,
#              'exigée': 1,
#              'sécurité': 3,
#              'intérieure': 1,
#              'doit': 5,
#              'durcir': 1,
#              'asile': 8,
#              'nationale': 3,
#              'que': 20,
#              'contre': 10,
#              'avec': 7,
#              'courage': 1,
#              'depuis': 2,
#              'modernisation': 3,
#              'qu': 7,
#              'umps': 1,
#              'el': 32,
#              'khomri': 31,
#              'présenté': 6,
#              'ce': 8,
#              'changera': 1,
#              'libre': 2,
#              'relatif': 7,
#              'gouvernement': 7,
#              'permettant': 4,
#              'lui': 1,
#              'a': 9,
#              'sru': 4,
#              'pénitentiaire': 8,
#              'faite': 1,
#              'mme': 1,
#              'juillet': 4,
#              'concernant': 3,
#              'sont': 7,
#              'prévoit': 9,
#              'transition': 3,
#              'interdisant': 4,
#              'constitutionnelle': 8,
#              'face': 2,
#              'marché': 6,
#              'portant': 5,
#              'réforme': 2,
#              'universelle': 1,
#              'celle': 1,
#              'toutefois': 3,
#              's': 4,
#              'contient': 1,
#              'bruxelles': 1,
#              'allemande': 1,
#              'impose': 2,
#              'adaptation': 1,
#              'approbation': 1,
#              'déposée': 6,
#              'big': 1,
#              'brother': 1,
#              'accélérant': 1,
#              'ultra': 2,
#              'laxiste': 2,
#              'peut': 2,
#              'cette': 8,
#              'invraisemblance': 1,
#              'même': 3,
#              'si': 2,
#              'dans': 9,
#              'renseignement': 8,
#              'dépassent': 1,
#              'gravement': 1,
#              'saisissant': 1,
#              'egalité': 1,
#              'expression': 1,
#              'là': 1,
#              'mermaz': 1,
#              'malandain': 1,
#              'nome': 7,
#              'financement': 10,
#              'anti': 4,
#              'terroriste': 1,
#              'habilitation': 2,
#              'bis': 1,
#              'fn': 1,
#              'réorganisation': 1,
#              'égalité': 3,
#              'effet': 2,
#              'un': 11,
#              'sera': 6,
#              'respectée': 2,
#              'ces': 2,
#              'méthodes': 1,
#              'alimentation': 3,
#              'fournisseurs': 1,
#              'au': 6,
#              'sénat': 4,
#              'liberticide': 3,
#              'appliquant': 1,
#              'juin': 1,
#              'prévoyant': 2,
#              'une': 11,
#              'mobilisation': 1,
#              'fondamentale': 4,
#              'encouragent': 1,
#              'politique': 3,
#              'sarkosy': 3,
#              'pécresse': 5,
#              'fioraso': 13,
#              'lru': 8,
#              'exigeant': 2,
#              'toute': 2,
#              'récente': 2,
#              'affirme': 3,
#              'plongé': 1,
#              'autorisant': 5,
#              'texte': 1,
#              'situation': 1,
#              'indigne': 1,
#              'dangereuse': 1,
#              'massivement': 1,
#              'fourre': 1,
#              'bruxelloise': 1,
#              'fermeté': 1,
#              'naturelle': 1,
#              'inexistant': 1,
#              'défient': 1,
#              'toubon': 5,
#              'québec': 1,
#              'réformant': 2,
#              'ou': 3,
#              'front': 2,
#              'premier': 1,
#              'mouvement': 1,
#              'sans': 3,
#              'maptam': 1,
#              'personnes': 1,
#              'relative': 5,
#              'dès': 2,
#              'mai': 2,
#              'besson': 1,
#              'savary': 2,
#              'orwellien': 1,
#              'vient': 4,
#              'obscur': 1,
#              'fruit': 1,
#              'désarmement': 1,
#              'régression': 1,
#              'administrative': 1,
#              'fake': 4,
#              'news': 2,
#              'présenterons': 1,
#              'orientation': 3,
#              'islamique': 4,
#              'étrange': 1,
#              'voyous': 2,
#              'handicap': 1,
#              'blanquer': 2,
#              'pompeusement': 1,
#              'met': 2,
#              'bruno': 2,
#              'bilde': 1,
#              'tepa': 1,
#              'honteuse': 1,
#              'complicité': 1,
#              'été': 6,
#              'pénale': 1,
#              'prétendu': 1,
#              'on': 1,
#              'décembre': 8,
#              'vigueur': 1,
#              'ainsi': 3,
#              'avenir': 2,
#              'censée': 4,
#              'protéger': 2,
#              'garantissant': 2,
#              'aussi': 2,
#              'soumise': 1,
#              'macro': 1,
#              'libérale': 1,
#              'actuellement': 2,
#              'va': 4,
#              'figure': 1,
#              'fois': 1,
#              'surtout': 2,
#              'vise': 4,
#              'revendications': 1,
#              'projet': 1,
#              'oublie': 1,
#              'taillée': 2,
#              'faveur': 2,
#              'http': 1,
#              'www': 1,
#              'se': 2,
#              'traduirait': 1,
#              'sapin': 1,
#              'apl': 1,
#              'durée': 1,
#              'madame': 2,
#              'transfert': 1,
#              'entend': 2,
#              'violer': 1,
#              'autorité': 1,
#              'marine': 3,
#              'bandes': 2,
#              'concerne': 1,
#              'main': 1,
#              'partout': 1,
#              'revient': 1,
#              'accord': 1,
#              'islamiste': 1,
#              'racailles': 1,
#              'délibérément': 1,
#              'oser': 1,
#              'soit': 4,
#              'enfin': 2,
#              'vont': 1,
#              'nouveau': 1,
#              'devait': 1,
#              'infâme': 1,
#              'rejetée': 1,
#              'socialiste': 4,
#              'fait': 2,
#              'eeg': 1,
#              'change': 1,
#              'cause': 1,
#              'économie': 1,
#              'élargir': 2,
#              'développer': 1,
#              'ultralibérale': 1,
#              'réduit': 1,
#              'avril': 1,
#              'ignoré': 1,
#              'strictement': 1,
#              'identique': 1,
#              'auront': 1,
#              'imposé': 1,
#              'éléments': 1,
#              'afin': 3,
#              'extension': 1,
#              'sanctionner': 1,
#              'alors': 5,
#              'anticonstitutionnel': 1,
#              'février': 2,
#              'souhaite': 1,
#              'casse': 1,
#              'cessons': 1,
#              'blasphème': 1,
#              'renforcée': 2,
#              'europe': 1,
#              'assemblée': 1,
#              'criminels': 1,
#              'entretiennent': 1,
#              'laisse': 1,
#              'substituer': 1,
#              'sombre': 1,
#              'était': 1,
#              'fut': 1,
#              'insensée': 1,
#              'bachelot': 4,
#              'radicale': 1,
#              'décidé': 1,
#              'm': 1,
#              'supprimant': 1,
#              'contrôler': 1,
#              'réussira': 1,
#              'précédente': 1,
#              'entrainant': 1,
#              'finalisée': 1,
#              'entre': 1,
#              'aujourd': 1,
#              'ayant': 2,
#              'ministère': 1,
#              'manuel': 1,
#              'cependant': 1,
#              'ministre': 1,
#              'donc': 2,
#              'extrêmement': 1,
#              'reste': 2,
#              'effrayante': 1,
#              'boîte': 1,
#              'sarkozy': 1,
#              'pinel': 2,
#              'aura': 1,
#              'aurait': 1,
#              'organisations': 1,
#              'faut': 1,
#              'destinées': 1,
#              'candidats': 1,
#              'celles': 1,
#              'ci': 2,
#              'précarisation': 1,
#              'son': 1,
#              'claire': 1,
#              'après': 2,
#              'examen': 1,
#              'cadre': 1,
#              'devrait': 2,
#              'prévoir': 1,
#              'immigration': 3,
#              'hypocrite': 1,
#              'favorisera': 1,
#              'aggravée': 1,
#              'indemnités': 1,
#              'toujours': 1,
#              'bref': 1,
#              'marchés': 1,
#              'second': 2,
#              'bafouée': 1,
#              'bioéthique': 1,
#              'ouvrant': 1,
#              'cadeau': 1,
#              'reconnaissant': 1,
#              'décentralisation': 1,
#              'celui': 1,
#              'méprise': 1,
#              'ani': 1,
#              'république': 2,
#              'autonomie': 1,
#              'mettrons': 1,
#              'millions': 1,
#              'notamment': 2,
#              'douste': 1,
#              'blazy': 1,
#              'derrière': 1,
#              'leur': 1,
#              'pressurer': 1,
#              'directives': 1,
#              'sommes': 1,
#              'mortifère': 1,
#              'seconde': 1,
#              'suivant': 1,
#              'veut': 1,
#              'insipide': 1,
#              'loin': 1,
#              'intérêts': 1,
#              'demander': 1,
#              'réformer': 2,
#              'soient': 1,
#              'couronner': 1,
#              'quel': 1,
#              'fera': 1,
#              'art': 1,
#              'mesures': 2,
#              'nécessaires': 1,
#              'ratification': 2,
#              'imposant': 1,
#              'je': 2,
#              'emplois': 1,
#              'rester': 1,
#              'retrouve': 1,
#              'rendra': 1,
#              'prévoirait': 1,
#              'petits': 1,
#              'certes': 1,
#              'duflot': 2,
#              'règlement': 2,
#              'interdiction': 2,
#              'cazeneuve': 1,
#              'yves': 1,
#              'ordinaires': 1,
#              'puissent': 1,
#              'révèle': 1,
#              'visiblement': 1,
#              'déjà': 1,
#              'caractérisée': 1,
#              'crée': 1,
#              'assouplit': 1,
#              'encore': 1,
#              'sorti': 1,
#              'pérennisant': 1,
#              'empêchant': 1,
#              'pays': 1,
#              'endiguer': 1,
#              'reconnaissance': 1,
#              'musulmane': 1,
#              'ils': 1,
#              'combattue': 1,
#              'pourrait': 1,
#              'ordonner': 1,
#              'pensais': 1,
#              'banques': 1,
#              'lieu': 1,
#              'répressive': 1,
#              'jospin': 1,
#              'plutôt': 1,
#              'conséquent': 1,
#              'participant': 1,
#              'martin': 1,
#              'hirsch': 1,
#              'voté': 1,
#              'dispose': 1,
#              'evin': 1,
#              'abrogée': 1,
#              'empêcher': 1,
#              'florange': 1,
#              'caïds': 1,
#              'justement': 1,
#              'excluant': 1,
#              'expressément': 1,
#              'permettait': 1,
#              'nos': 2,
#              'américaine': 2,
#              'intitulée': 1,
#              'léonetti': 2,
#              'clair': 1,
#              'scélérate': 1,
#              'modifiant': 1,
#              'modifierait': 1,
#              'profondément': 1,
#              'laxisme': 1,
#              'haby': 1,
#              'instaurant': 1,
#              'serait': 1,
#              'examiné': 1,
#              'proposée': 1,
#              'doivent': 1,
#              'être': 1,
#              'répond': 1,
#              'moralisation': 1,
#              'janvier': 1,
#              'vous': 1,
#              'ordinaire': 2,
#              'conclut': 1,
#              'puisse': 2,
#              'désormais': 1,
#              'foulés': 1,
#              'demande': 1,
#              'devons': 1,
#              'ses': 2,
#              'appelé': 1,
#              'refondation': 1,
#              'peillon': 1,
#              'priver': 1,
#              'août': 2,
#              'venant': 1,
#              'renforcer': 1,
#              'commission': 1,
#              'état': 1,
#              'protégeant': 1,
#              'abaissant': 1,
#              'porte': 1,
#              'subventionnant': 1,
#              'révision': 1,
#              'comment': 1,
#              'renforçant': 1,
#              'soulève': 1,
#              'jeudi': 1,
#              'réclamée': 1,
#              'nécessaire': 1,
#              'constitutionnel': 1,
#              'peine': 1,
#              'lançant': 1,
#              'bertrand': 1,
#              'louvel': 1,
#              'nul': 1,
#              'besoin': 1,
#              'littoral': 1,
#              'graver': 1,
#              'attendue': 1,
#              '?': 1,
#              '«': 6,
#              'confortant': 2,
#              '(placement': 1,
#              'egalim': 4,
#              'avia),': 1,
#              'défend': 1,
#              'rendre': 1,
#              '»': 2,
#              'trafiquants': 1,
#              'pacte,': 2,
#              'finance,': 1,
#              'permettrait': 1,
#              'commune,': 1,
#              'quelle': 1,
#              'française.': 1,
#              'européenne': 2,
#              'khomri.': 1,
#              'kouchner': 1,
#              '».': 1,
#              'présente': 1,
#              'hélas': 1,
#              '22': 1,
#              'finances,': 2,
#              'proposera': 1,
#              'l’interdiction': 1,
#              'solidarité': 1,
#              'sous': 1,
#              'parisianiste': 1,
#              's’est': 1,
#              'ouvre': 1,
#              'egalim.': 1,
#              'promulguée': 2,
#              'n°879': 1,
#              '2020': 1,
#              'n°2255': 1,
#              'originale': 1,
#              'pouvait': 1,
#              '25': 1,
#              'egalim,': 1,
#              'disposition': 1,
#              'venait': 1,
#              'd’être': 1,
#              'l’équilibre': 1,
#              '»,': 1,
#              'imposer': 1,
#              'interdit': 1,
#              'pécresse/sarkozy': 1,
#              '!': 2,
#              'souhaitent': 1,
#              'lutte': 2,
#              'climat.': 1,
#              'certaines': 1,
#              '11': 1,
#              'n’a': 1,
#              'pas': 1,
#              'représente': 1,
#              'd’un': 1,
#              'député': 1,
#              'avia': 2,
#              'fake-news».': 1,
#              'd’urgence': 1,
#              'islamique.': 1,
#              'girard': 1,
#              '.la': 1,
#              'condamne': 1,
#              '24': 1,
#              'programme': 1,
#              '21/07/2003.': 1,
#              'ont': 1,
#              '2020.': 1,
#              'fumeux': 1,
#              'hondt': 1,
#              'climat': 4,
#              '.': 1,
#              'menace': 1,
#              'co2': 1,
#              'antiterroriste,': 1,
#              'et,': 1,
#              'prétend': 1,
#              'vouloir': 1,
#              'bienvenu,': 1,
#              'avait': 1,
#              'référendaire': 2,
#              'vigilance': 1,
#              'voteront': 1,
#              'coquille': 1,
#              'redevient': 1,
#              'ambitieuse,': 1,
#              'également.': 1,
#              'détriment': 1,
#              'polonais': 1,
#              'liberticide,': 1,
#              'avaient': 1,
#              '30': 1,
#              '2021': 2,
#              'bandes,': 1,
#              'finances.': 1,
#              'chaque': 1,
#              'année,': 1,
#              'propose': 1,
#              'également': 1})

# %%
model.get_obj_stereotypes_vector(vector)
# Out:
# [{'dimension': 2965,
#   'value': True,
#   'stereotypes': [(0.1, 'dgfip'),
#    (0.09, 'rectificative'),
#    (0.07, 'akinwumi')]},
#  {'dimension': 1025,
#   'value': True,
#   'stereotypes': [(0.03, 'el'), (0.02, 'élocution'), (0.02, 'bamakois')]},
#  {'dimension': 2639,
#   'value': True,
#   'stereotypes': [(0.09, 'extraditions'),
#    (0.08, 'apuiat'),
#    (0.06, 'transcanada')]},
#  {'dimension': 6506,
#   'value': True,
#   'stereotypes': [(0.06, 'pluriannuelle'),
#    (0.03, 'éclectique'),
#    (0.03, 'quinquennale')]},
#  {'dimension': 431,
#   'value': True,
#   'stereotypes': [(0.06, 'harassant'), (0.06, 'talla'), (0.06, 'cnesst')]}]

# %%
mot = "ecologie"
f = open("/lium/raid01_c/sguillot/Corpus/HackaTAL/"+mot+"_rn.pk", 'rb')
dico = pk.load(f)
f.close()
vector = model.transfert_hackatal(mot, dico)
model.most_similar_vector(mot,vector.reshape(1, -1))
# Out:
# {'object ': 'ecologie',
#  'neighbors ': [('écologie', 0.3),
#   ('durable', 0.25),
#   ('aprèsvente', 0.23),
#   ('odd', 0.22),
#   ('expédition', 0.22),
#   ('socioéconomique', 0.21),
#   ('prônée', 0.21),
#   ('harmonieux', 0.2),
#   ('verts', 0.2),
#   ('pndes', 0.19),
#   ('levier', 0.18),
#   ('terror', 0.17),
#   ('anticapitaliste', 0.17),
#   ('économique', 0.17),
#   ('endogène', 0.16),
#   ('espaces', 0.16),
#   ('échiquier', 0.16),
#   ('economique', 0.16),
#   ('limogée', 0.16),
#   ('civique', 0.16),
#   ('volontariste', 0.16),
#   ('inclusif', 0.16),
#   ('humain', 0.16),
#   ('environnement', 0.15)]}

# %%
model.get_obj_stereotypes_vector(vector)
# Out:
# [{'dimension': 6736,
#   'value': True,
#   'stereotypes': [(0.08, 'punitive'),
#    (0.03, 'terror'),
#    (0.02, 'microplastiques')]},
#  {'dimension': 6619,
#   'value': True,
#   'stereotypes': [(0.09, 'odd'), (0.09, 'durable'), (0.06, 'recrutons')]},
#  {'dimension': 2632,
#   'value': True,
#   'stereotypes': [(0.1, 'aprèsvente'),
#    (0.06, 'pneumologie'),
#    (0.05, 'feedly')]},
#  {'dimension': 4580,
#   'value': True,
#   'stereotypes': [(0.02, 'gnoka'),
#    (0.02, 'airsoft'),
#    (0.02, 'extrapolation')]},
#  {'dimension': 2000,
#   'value': True,
#   'stereotypes': [(0.05, 'réussirait'),
#    (0.05, 'verts'),
#    (0.04, 'kalabancoro')]}]

# %%
f = open("/lium/raid01_c/sguillot/Corpus/HackaTAL/"+mot+"_fi.pk", 'rb')
dico = pk.load(f)
f.close()
vector = model.transfert_hackatal(mot, dico)
model.most_similar_vector(mot,vector.reshape(1, -1))

# %%
dico
# Out:
# defaultdict(int,
#             {'y': 1,
#              'compris': 1,
#              'doit': 1,
#              'se': 1,
#              'est': 1,
#              'l': 1,
#              's': 1,
#              'inscrivent': 1,
#              'capitaliste': 1,
#              'que': 1,
#              'populaire': 3,
#              'nous': 1,
#              'sera': 1,
#              'et': 1,
#              'de': 1,
#              'populaire,': 2,
#              'seul': 1,
#              'démocratie': 1,
#              'solidarité': 1,
#              'l’option': 1,
#              'sur': 1,
#              'les': 1,
#              'retards': 1,
#              'français': 1,
#              'dont': 1,
#              'macron': 1,
#              'envoie': 1})

# %%
model.get_obj_stereotypes_vector(vector)
# Out:
# [{'dimension': 2234,
#   'value': True,
#   'stereotypes': [(0.07, 'anp'), (0.07, 'vindicte'), (0.06, 'mdn')]},
#  {'dimension': 1205,
#   'value': True,
#   'stereotypes': [(0.07, 'déchirements'), (0.04, 'pétri'), (0.03, 'snvi')]},
#  {'dimension': 3767,
#   'value': True,
#   'stereotypes': [(0.04, 'baroin'), (0.03, 'bayrou'), (0.03, 'jubilent')]},
#  {'dimension': 4292,
#   'value': True,
#   'stereotypes': [(0.1, 'collatérale'),
#    (0.05, 'désincarcérer'),
#    (0.05, 'transportée')]},
#  {'dimension': 3132,
#   'value': True,
#   'stereotypes': [(0.07, 'impardonnables'),
#    (0.06, 'commises'),
#    (0.05, 'omissions')]}]

# %%
mot = "police"
f = open("/lium/raid01_c/sguillot/Corpus/HackaTAL/"+mot+"_fi.pk", 'rb')
dico = pk.load(f)
f.close()
vector = model.transfert_hackatal(mot, dico)
model.most_similar_vector(mot,vector.reshape(1, -1))
# Out:
# {'object ': 'police',
#  'neighbors ': [('soulèvement', 0.42),
#   ('anp', 0.36),
#   ('insurrection', 0.33),
#   ('mdn', 0.31),
#   ('votation', 0.29),
#   ('ferveur', 0.28),
#   ('populaire', 0.27),
#   ('liesse', 0.27),
#   ('détachement', 0.24),
#   ('détachements', 0.24),
#   ('éducatif', 0.23),
#   ('militarisée', 0.22),
#   ('immunitaire', 0.2),
#   ('subliminal', 0.2),
#   ('croyance', 0.2),
#   ('soustitré', 0.2),
#   ('capitaliste', 0.19),
#   ('tissemsilt', 0.19),
#   ('dicton', 0.19),
#   ('élan', 0.19),
#   ('complainte', 0.19),
#   ('révolte', 0.19),
#   ('élitiste', 0.19),
#   ('badji', 0.18)]}

# %%
dico
# Out:
# defaultdict(int,
#             {'y': 1,
#              'compris': 1,
#              'doit': 1,
#              'se': 1,
#              'est': 1,
#              'l': 1,
#              's': 1,
#              'inscrivent': 1,
#              'capitaliste': 1,
#              'que': 1,
#              'populaire': 3,
#              'nous': 1,
#              'sera': 1,
#              'et': 1,
#              'de': 1,
#              'populaire,': 2,
#              'seul': 1,
#              'démocratie': 1,
#              'solidarité': 1,
#              'l’option': 1,
#              'sur': 1,
#              'les': 1,
#              'retards': 1,
#              'français': 1,
#              'dont': 1,
#              'macron': 1,
#              'envoie': 1})
